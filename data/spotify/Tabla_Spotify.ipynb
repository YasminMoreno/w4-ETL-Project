# %%
import pandas as pd

import numpy as np

import random

from sqlalchemy import create_engine

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # TOP 1 de Spotify en Canada (Enero - Septiembre 2022):

# %%
#csv canada

canada_enero=pd.read_csv('../spotify/canada_1_enero.csv')
canada_febrero=pd.read_csv('../spotify/canada_1_febrero.csv')
canada_marzo=pd.read_csv('../spotify/canada_1_marzo.csv')
canada_abril=pd.read_csv('../spotify/canada_1_abril.csv')
canada_mayo=pd.read_csv('../spotify/canada_1_mayo.csv')
canada_junio=pd.read_csv('../spotify/canada_1_junio.csv')
canada_julio=pd.read_csv('../spotify/canada_1_julio.csv')
canada_agosto=pd.read_csv('../spotify/canada_1_agosto.csv')
canada_septiembre=pd.read_csv('../spotify/canada_1_septiembre.csv')


canada_enero.head()
# Out:
#    rank                                   uri                  artist_names  \
# 0     1  spotify:track:7rglLriMNBPAyuJOMGwi39    Elton John, Dua Lipa, PNAU
# 1     2  spotify:track:5PjdY0CKGZdEuoNab3yDmX  The Kid LAROI, Justin Bieber
# 2     3  spotify:track:02MWAaffLxlfxAUY7c5dvx                 Glass Animals
# 3     4  spotify:track:5Z9KJZvQzH6PFmb8SNkxuk        Lil Nas X, Jack Harlow
# 4     5  spotify:track:4fouWK6XVHhzl78KzQ1UjL                         GAYLE
#
#                           track_name                     source  peak_rank  \
# 0            Cold Heart - PNAU Remix                        EMI          1
# 1          STAY (with Justin Bieber)                   Columbia          1
# 2                         Heat Waves            Polydor Records          3
# 3  INDUSTRY BABY (feat. Jack Harlow)                   Columbia          1
# 4                            abcdefu  Atlantic/Arthouse Records          3
#
#    previous_rank  days_on_chart  streams
# ...

# %%
canada_1 = canada_enero.iloc[0]
canada_2 = canada_febrero.iloc[0]
canada_3 = canada_marzo.iloc[0]
canada_4 = canada_abril.iloc[0]
canada_5 = canada_mayo.iloc[0]
canada_6 = canada_junio.iloc[0]
canada_7 = canada_julio.iloc[0]
canada_8 = canada_agosto.iloc[0]
canada_9 = canada_septiembre.iloc[0]

canada_1
# Out:
# rank                                                1
# uri              spotify:track:7rglLriMNBPAyuJOMGwi39
# artist_names               Elton John, Dua Lipa, PNAU
# track_name                    Cold Heart - PNAU Remix
# source                                            EMI
# peak_rank                                           1
# previous_rank                                       1
# days_on_chart                                     142
# streams                                        206749
# Name: 0, dtype: object

# %%
top_canada1 = pd.DataFrame(canada_1).T
top_canada2 = pd.DataFrame(canada_2).T
top_canada3 = pd.DataFrame(canada_3).T
top_canada4 = pd.DataFrame(canada_4).T
top_canada5 = pd.DataFrame(canada_5).T
top_canada6 = pd.DataFrame(canada_6).T
top_canada7 = pd.DataFrame(canada_7).T
top_canada8 = pd.DataFrame(canada_8).T
top_canada9 = pd.DataFrame(canada_9).T

top_canada1
# Out:
#   rank                                   uri                artist_names  \
# 0    1  spotify:track:7rglLriMNBPAyuJOMGwi39  Elton John, Dua Lipa, PNAU
#
#                 track_name source peak_rank previous_rank days_on_chart  \
# 0  Cold Heart - PNAU Remix    EMI         1             1           142
#
#   streams
# 0  206749

# %%
top_canada = pd.concat([top_canada1, top_canada2, top_canada3, top_canada4, top_canada5, top_canada6, top_canada7, top_canada8, top_canada9], axis=0)

top_canada
# Out:
#   rank                                   uri  \
# 0    1  spotify:track:7rglLriMNBPAyuJOMGwi39
# 0    1  spotify:track:52xJxFP6TqMuO4Yt0eOkMz
# 0    1  spotify:track:02MWAaffLxlfxAUY7c5dvx
# 0    1  spotify:track:4LRPiXqCikLlN15c3yImP7
# 0    1  spotify:track:4LRPiXqCikLlN15c3yImP7
# 0    1  spotify:track:75FEaRjZTKLhTrFGsfMUXR
# 0    1  spotify:track:3F5CgOj3wFlRv51JsHbxhe
# 0    1  spotify:track:4Dvkj6JhhA12EX05fT7y2e
# 0    1  spotify:track:2yjlYDiNiQkdxVqTlaSrlX
#
#                                         artist_names  \
# 0                         Elton John, Dua Lipa, PNAU
# 0  Carolina Gaitán - La Gaita, Mauro Castillo, Ad...
# 0                                      Glass Animals
# 0                                       Harry Styles
# 0                                       Harry Styles
# 0                                          Kate Bush
# 0                                   Drake, 21 Savage
# 0                                       Harry Styles
# ...

# %%
top_canada['date'] = ('2022-1-1', '2022-2-1', '2022-3-1', '2022-4-1', '2022-5-1', '2022-6-1', '2022-7-1', '2022-8-1', '2022-9-1')
top_canada['country'] = ('Canada')

top_canada
# Out:
#   rank                                   uri  \
# 0    1  spotify:track:7rglLriMNBPAyuJOMGwi39
# 0    1  spotify:track:52xJxFP6TqMuO4Yt0eOkMz
# 0    1  spotify:track:02MWAaffLxlfxAUY7c5dvx
# 0    1  spotify:track:4LRPiXqCikLlN15c3yImP7
# 0    1  spotify:track:4LRPiXqCikLlN15c3yImP7
# 0    1  spotify:track:75FEaRjZTKLhTrFGsfMUXR
# 0    1  spotify:track:3F5CgOj3wFlRv51JsHbxhe
# 0    1  spotify:track:4Dvkj6JhhA12EX05fT7y2e
# 0    1  spotify:track:2yjlYDiNiQkdxVqTlaSrlX
#
#                                         artist_names  \
# 0                         Elton John, Dua Lipa, PNAU
# 0  Carolina Gaitán - La Gaita, Mauro Castillo, Ad...
# 0                                      Glass Animals
# 0                                       Harry Styles
# 0                                       Harry Styles
# 0                                          Kate Bush
# 0                                   Drake, 21 Savage
# 0                                       Harry Styles
# ...

# %% [markdown]
# # TOP 1 de Spotify en USA (Enero - Septiembre 2022):

# %%
#csv usa

usa_enero=pd.read_csv('../spotify/usa_1_enero.csv')
usa_febrero=pd.read_csv('../spotify/usa_1_febrero.csv')
usa_marzo=pd.read_csv('../spotify/usa_1_marzo.csv')
usa_abril=pd.read_csv('../spotify/usa_1_abril.csv')
usa_mayo=pd.read_csv('../spotify/usa_1_mayo.csv')
usa_junio=pd.read_csv('../spotify/usa_1_junio.csv')
usa_julio=pd.read_csv('../spotify/usa_1_julio.csv')
usa_agosto=pd.read_csv('../spotify/usa_1_agosto.csv')
usa_septiembre=pd.read_csv('../spotify/usa_1_septiembre.csv')

# %%
usa_1 = usa_enero.iloc[0]
usa_2 = usa_febrero.iloc[0]
usa_3 = usa_marzo.iloc[0]
usa_4 = usa_abril.iloc[0]
usa_5 = usa_mayo.iloc[0]
usa_6 = usa_junio.iloc[0]
usa_7 = usa_julio.iloc[0]
usa_8 = usa_agosto.iloc[0]
usa_9 = usa_septiembre.iloc[0]

# %%
top_usa1 = pd.DataFrame(usa_1).T
top_usa2 = pd.DataFrame(usa_2).T
top_usa3 = pd.DataFrame(usa_3).T
top_usa4 = pd.DataFrame(usa_4).T
top_usa5 = pd.DataFrame(usa_5).T
top_usa6 = pd.DataFrame(usa_6).T
top_usa7 = pd.DataFrame(usa_7).T
top_usa8 = pd.DataFrame(usa_8).T
top_usa9 = pd.DataFrame(usa_9).T

# %%
top_usa = pd.concat([top_usa1, top_usa2, top_usa3, top_usa4, top_usa5, top_usa6, top_usa7, top_usa8, top_usa9], axis=0)

# %%
top_usa['date'] = ('2022-1-1', '2022-2-1', '2022-3-1', '2022-4-1', '2022-5-1', '2022-6-1', '2022-7-1', '2022-8-1', '2022-9-1')
top_usa['country'] = ('USA')

top_usa
# Out:
#   rank                                   uri  \
# 0    1  spotify:track:02MWAaffLxlfxAUY7c5dvx
# 0    1  spotify:track:52xJxFP6TqMuO4Yt0eOkMz
# 0    1  spotify:track:02MWAaffLxlfxAUY7c5dvx
# 0    1  spotify:track:4LRPiXqCikLlN15c3yImP7
# 0    1  spotify:track:4LRPiXqCikLlN15c3yImP7
# 0    1  spotify:track:75FEaRjZTKLhTrFGsfMUXR
# 0    1  spotify:track:75FEaRjZTKLhTrFGsfMUXR
# 0    1  spotify:track:4k6Uh1HXdhtusDW5y8Gbvy
# 0    1  spotify:track:4k6Uh1HXdhtusDW5y8Gbvy
#
#                                         artist_names  \
# 0                                      Glass Animals
# 0  Carolina Gaitán - La Gaita, Mauro Castillo, Ad...
# 0                                      Glass Animals
# 0                                       Harry Styles
# 0                                       Harry Styles
# 0                                          Kate Bush
# 0                                          Kate Bush
# 0                                         Steve Lacy
# ...

# %% [markdown]
# # TOP 1 de Spotify en Argentina (Enero - Septiembre 2022):

# %%
#csv argentina

argentina_enero=pd.read_csv('../spotify/argentina_1_enero.csv')
argentina_febrero=pd.read_csv('../spotify/argentina_1_febrero.csv')
argentina_marzo=pd.read_csv('../spotify/argentina_1_marzo.csv')
argentina_abril=pd.read_csv('../spotify/argentina_1_abril.csv')
argentina_mayo=pd.read_csv('../spotify/argentina_1_mayo.csv')
argentina_junio=pd.read_csv('../spotify/argentina_1_junio.csv')
argentina_julio=pd.read_csv('../spotify/argentina_1_julio.csv')
argentina_agosto=pd.read_csv('../spotify/argentina_1_agosto.csv')
argentina_septiembre=pd.read_csv('../spotify/argentina_1_septiembre.csv')


argentina_enero.head()
# Out:
#    rank                                   uri         artist_names  \
# 0     1  spotify:track:0lJE8f0lx8mUSfMyxeYpiC        TINI, L-Gante
# 1     2  spotify:track:5fBQLapwAPSLw27STml9kr          Salastkbron
# 2     3  spotify:track:2Gq636OOGgxCTqEuzCZhsa  Bizarrap, Tiago PZK
# 3     4  spotify:track:6P096SaOzrgGxs8NWOfX7M    Tiago PZK, Trueno
# 4     5  spotify:track:1kjs5eR4DMzyB0gm1Z8waV               Trueno
#
#                                 track_name  \
# 0                                      Bar
# 1                                    TITAN
# 2  Tiago PZK: Bzrp Music Sessions, Vol. 48
# 3                          Salimo de Noche
# 4                               DANCE CRIP
#
#                                               source  peak_rank  \
# 0                                   Sony Music Latin          1
# 1                                       WM Argentina          2
# 2                       WEA Latina/DALE PLAY Records          1
# ...

# %%
argentina_1 = argentina_enero.iloc[0]
argentina_2 = argentina_febrero.iloc[0]
argentina_3 = argentina_marzo.iloc[0]
argentina_4 = argentina_abril.iloc[0]
argentina_5 = argentina_mayo.iloc[0]
argentina_6 = argentina_junio.iloc[0]
argentina_7 = argentina_julio.iloc[0]
argentina_8 = argentina_agosto.iloc[0]
argentina_9 = argentina_septiembre.iloc[0]

# %%
top_argentina1 = pd.DataFrame(argentina_1).T
top_argentina2 = pd.DataFrame(argentina_2).T
top_argentina3 = pd.DataFrame(argentina_3).T
top_argentina4 = pd.DataFrame(argentina_4).T
top_argentina5 = pd.DataFrame(argentina_5).T
top_argentina6 = pd.DataFrame(argentina_6).T
top_argentina7 = pd.DataFrame(argentina_7).T
top_argentina8 = pd.DataFrame(argentina_8).T
top_argentina9 = pd.DataFrame(argentina_9).T

# %%
top_argentina = pd.concat([top_argentina1, top_argentina2, top_argentina3, top_argentina4, top_argentina5, top_argentina6, top_argentina7, top_argentina8, top_argentina9], axis=0)

# %%
top_argentina['date'] = ('2022-1-1', '2022-2-1', '2022-3-1', '2022-4-1', '2022-5-1', '2022-6-1', '2022-7-1', '2022-8-1', '2022-9-1')
top_argentina['country'] = ('Argentina')

top_argentina
# Out:
#   rank                                   uri  \
# 0    1  spotify:track:0lJE8f0lx8mUSfMyxeYpiC
# 0    1  spotify:track:2Gq636OOGgxCTqEuzCZhsa
# 0    1  spotify:track:6mmPpaltUZK7xjNlBPQQ0p
# 0    1  spotify:track:2gpQi3hbcUAcEG8m2dlgfB
# 0    1  spotify:track:2uky0VCI2EZni0nArOPznM
# 0    1  spotify:track:7kYbxvrGXv8cmKjkqgqhrw
# 0    1  spotify:track:3k3NWokhRRkEPhCzPmV8TW
# 0    1  spotify:track:2tTmW7RDtMQtBk7m2rYeSw
# 0    1  spotify:track:5ww2BF9slyYgNOk37BlC4u
#
#                        artist_names  \
# 0                     TINI, L-Gante
# 0               Bizarrap, Tiago PZK
# 0  Rauw Alejandro, Chencho Corleone
# 0                      Paulo Londra
# 0            Bizarrap, Paulo Londra
# 0                              TINI
# 0          Bad Bunny, Bomba Estéreo
# 0                 Bizarrap, Quevedo
# 0                     Manuel Turizo
#
#                                    track_name  \
# 0                                         Bar
# ...

# %% [markdown]
# # TOP 1 de Spotify en Colombia (Enero - Septiembre 2022):

# %%
#csv colombia

colombia_enero=pd.read_csv('../spotify/colombia_1_enero.csv')
colombia_febrero=pd.read_csv('../spotify/colombia_1_febrero.csv')
colombia_marzo=pd.read_csv('../spotify/colombia_1_marzo.csv')
colombia_abril=pd.read_csv('../spotify/colombia_1_abril.csv')
colombia_mayo=pd.read_csv('../spotify/colombia_1_mayo.csv')
colombia_junio=pd.read_csv('../spotify/colombia_1_junio.csv')
colombia_julio=pd.read_csv('../spotify/colombia_1_julio.csv')
colombia_agosto=pd.read_csv('../spotify/colombia_1_agosto.csv')
colombia_septiembre=pd.read_csv('../spotify/colombia_1_septiembre.csv')


colombia_enero.head()
# Out:
#    rank                                   uri  \
# 0     1  spotify:track:1JpzJfxjHGFUyTHXLZidok
# 1     2  spotify:track:6lX6l7OuA3qrnIRfdsr0dw
# 2     3  spotify:track:7mSmItMB11IWTIEOVKLxuG
# 3     4  spotify:track:17jcYtUYRhpPL19fDedfTD
# 4     5  spotify:track:2JPLbjOn0wPCngEot2STUS
#
#                            artist_names        track_name  \
# 0                     Ryan Castro, Feid         Monastery
# 1  Blessd, Justin Quiles, Lenny Tavárez           Medallo
# 2                        Néstor Zavarce  Cinco Pa' las 12
# 3                           Ryan Castro         Wasa Wasa
# 4                             Bad Bunny          Yonaguni
#
#                     source  peak_rank  previous_rank  days_on_chart  streams
# 0            UMLE - Latino          1              1             51   136178
# 1               WEA Latina          1              2             67   119854
# 2            Los Mélodicos          3             82             17   113583
# ...

# %%
colombia_1 = colombia_enero.iloc[0]
colombia_2 = colombia_febrero.iloc[0]
colombia_3 = colombia_marzo.iloc[0]
colombia_4 = colombia_abril.iloc[0]
colombia_5 = colombia_mayo.iloc[0]
colombia_6 = colombia_junio.iloc[0]
colombia_7 = colombia_julio.iloc[0]
colombia_8 = colombia_agosto.iloc[0]
colombia_9 = colombia_septiembre.iloc[0]

# %%
top_colombia1 = pd.DataFrame(colombia_1).T
top_colombia2 = pd.DataFrame(colombia_2).T
top_colombia3 = pd.DataFrame(colombia_3).T
top_colombia4 = pd.DataFrame(colombia_4).T
top_colombia5 = pd.DataFrame(colombia_5).T
top_colombia6 = pd.DataFrame(colombia_6).T
top_colombia7 = pd.DataFrame(colombia_7).T
top_colombia8 = pd.DataFrame(colombia_8).T
top_colombia9 = pd.DataFrame(colombia_9).T

# %%
top_colombia = pd.concat([top_colombia1, top_colombia2, top_colombia3, top_colombia4, top_colombia5, top_colombia6, top_colombia7, top_colombia8, top_colombia9], axis=0)

# %%
top_colombia['date'] = ('2022-1-1', '2022-2-1', '2022-3-1', '2022-4-1', '2022-5-1', '2022-6-1', '2022-7-1', '2022-8-1', '2022-9-1')
top_colombia['country'] = ('Colombia')

top_colombia
# Out:
#   rank                                   uri                 artist_names  \
# 0    1  spotify:track:1JpzJfxjHGFUyTHXLZidok            Ryan Castro, Feid
# 0    1  spotify:track:1JpzJfxjHGFUyTHXLZidok            Ryan Castro, Feid
# 0    1  spotify:track:1ri9ZUkBJVFUdgwzCnfcYs             Becky G, KAROL G
# 0    1  spotify:track:4srcMdbm2qzVG98tJajHxp            Alejo, Feid, ROBI
# 0    1  spotify:track:7dSZ6zGTQx66c2GF91xCrb                      KAROL G
# 0    1  spotify:track:6Sq7ltF9Qa7SNFBsV5Cogx  Bad Bunny, Chencho Corleone
# 0    1  spotify:track:6Sq7ltF9Qa7SNFBsV5Cogx  Bad Bunny, Chencho Corleone
# 0    1  spotify:track:2tTmW7RDtMQtBk7m2rYeSw            Bizarrap, Quevedo
# 0    1  spotify:track:2tTmW7RDtMQtBk7m2rYeSw            Bizarrap, Quevedo
#
#                               track_name                        source  \
# 0                              Monastery                 UMLE - Latino
# 0                              Monastery                 UMLE - Latino
# ...

# %% [markdown]
# # TOP 1 de Spotify en España (Enero - Septiembre 2022):

# %%
#csv spain

spain_enero=pd.read_csv('../spotify/spain_1_enero.csv')
spain_febrero=pd.read_csv('../spotify/spain_1_febrero.csv')
spain_marzo=pd.read_csv('../spotify/spain_1_marzo.csv')
spain_abril=pd.read_csv('../spotify/spain_1_abril.csv')
spain_mayo=pd.read_csv('../spotify/spain_1_mayo.csv')
spain_junio=pd.read_csv('../spotify/spain_1_junio.csv')
spain_julio=pd.read_csv('../spotify/spain_1_julio.csv')
spain_agosto=pd.read_csv('../spotify/spain_1_agosto.csv')
spain_septiembre=pd.read_csv('../spotify/spain_1_septiembre.csv')


spain_enero.head()
# Out:
#    rank                                   uri  \
# 0     1  spotify:track:2Gq636OOGgxCTqEuzCZhsa
# 1     2  spotify:track:5h5TUj8pU2WhdSeJx9BnX2
# 2     3  spotify:track:39yyHtQ4tkjZzd8TfIBKQw
# 3     4  spotify:track:6mmPpaltUZK7xjNlBPQQ0p
# 4     5  spotify:track:5TMLavqGRKNxgzMBrVpC9R
#
#                        artist_names                               track_name  \
# 0               Bizarrap, Tiago PZK  Tiago PZK: Bzrp Music Sessions, Vol. 48
# 1                             Morad                                   Pelele
# 2                   Bizarrap, Morad      Morad: Bzrp Music Sessions, Vol. 47
# 3  Rauw Alejandro, Chencho Corleone                             Desesperados
# 4                    zzoilo, Aitana                        Mon Amour - Remix
#
#                                  source  peak_rank  previous_rank  \
# 0          WEA Latina/DALE PLAY Records          1              1
# 1                               M.D.L.R          1              4
# ...

# %%
spain_1 = spain_enero.iloc[0]
spain_2 = spain_febrero.iloc[0]
spain_3 = spain_marzo.iloc[0]
spain_4 = spain_abril.iloc[0]
spain_5 = spain_mayo.iloc[0]
spain_6 = spain_junio.iloc[0]
spain_7 = spain_julio.iloc[0]
spain_8 = spain_agosto.iloc[0]
spain_9 = spain_septiembre.iloc[0]

# %%
top_spain1 = pd.DataFrame(spain_1).T
top_spain2 = pd.DataFrame(spain_2).T
top_spain3 = pd.DataFrame(spain_3).T
top_spain4 = pd.DataFrame(spain_4).T
top_spain5 = pd.DataFrame(spain_5).T
top_spain6 = pd.DataFrame(spain_6).T
top_spain7 = pd.DataFrame(spain_7).T
top_spain8 = pd.DataFrame(spain_8).T
top_spain9 = pd.DataFrame(spain_9).T

# %%
top_spain = pd.concat([top_spain1, top_spain2, top_spain3, top_spain4, top_spain5, top_spain6, top_spain7, top_spain8, top_spain9], axis=0)

# %%
top_spain['date'] = ('2022-1-1', '2022-2-1', '2022-3-1', '2022-4-1', '2022-5-1', '2022-6-1', '2022-7-1', '2022-8-1', '2022-9-1')
top_spain['country'] = ('Spain')

top_spain
# Out:
#   rank                                   uri  \
# 0    1  spotify:track:2Gq636OOGgxCTqEuzCZhsa
# 0    1  spotify:track:0Bv7O6fmZk3GrNQFYJaXPn
# 0    1  spotify:track:0Bv7O6fmZk3GrNQFYJaXPn
# 0    1  spotify:track:4srcMdbm2qzVG98tJajHxp
# 0    1  spotify:track:2uky0VCI2EZni0nArOPznM
# 0    1  spotify:track:1IHWl5LamUGEuP4ozKQSXZ
# 0    1  spotify:track:1IHWl5LamUGEuP4ozKQSXZ
# 0    1  spotify:track:2tTmW7RDtMQtBk7m2rYeSw
# 0    1  spotify:track:2tTmW7RDtMQtBk7m2rYeSw
#
#                                         artist_names  \
# 0                                Bizarrap, Tiago PZK
# 0  La Pantera, Quevedo, Juseph, Abhir Hathi, Bejo...
# 0  La Pantera, Quevedo, Juseph, Abhir Hathi, Bejo...
# 0                                  Alejo, Feid, ROBI
# 0                             Bizarrap, Paulo Londra
# 0                                          Bad Bunny
# 0                                          Bad Bunny
# 0                                  Bizarrap, Quevedo
# ...

# %% [markdown]
# # TOP 1 de Spotify en UK (Enero - Septiembre 2022):

# %%
#csv uk

uk_enero=pd.read_csv('../spotify/uk_1_enero.csv')
uk_febrero=pd.read_csv('../spotify/uk_1_febrero.csv')
uk_marzo=pd.read_csv('../spotify/uk_1_marzo.csv')
uk_abril=pd.read_csv('../spotify/uk_1_abril.csv')
uk_mayo=pd.read_csv('../spotify/uk_1_mayo.csv')
uk_junio=pd.read_csv('../spotify/uk_1_junio.csv')
uk_julio=pd.read_csv('../spotify/uk_1_julio.csv')
uk_agosto=pd.read_csv('../spotify/uk_1_agosto.csv')
uk_septiembre=pd.read_csv('../spotify/uk_1_septiembre.csv')


uk_enero.head()
# Out:
#    rank                                   uri                artist_names  \
# 0     1  spotify:track:46IZ0fSY2mpAiktS3KOqds                       Adele
# 1     2  spotify:track:50nfwKoDiSYg8zOCREWAm5                  Ed Sheeran
# 2     3  spotify:track:3rmo8F54jFF8OgYsqTxm5d                  Ed Sheeran
# 3     4  spotify:track:4fouWK6XVHhzl78KzQ1UjL                       GAYLE
# 4     5  spotify:track:7rglLriMNBPAyuJOMGwi39  Elton John, Dua Lipa, PNAU
#
#                 track_name                     source  peak_rank  \
# 0               Easy On Me                   Columbia          1
# 1                  Shivers        Atlantic Records UK          1
# 2               Bad Habits        Atlantic Records UK          1
# 3                  abcdefu  Atlantic/Arthouse Records          2
# 4  Cold Heart - PNAU Remix                        EMI          2
#
#    previous_rank  days_on_chart  streams
# 0              3             80   232484
# 1              5            114   205116
# ...

# %%
uk_1 = uk_enero.iloc[0]
uk_2 = uk_febrero.iloc[0]
uk_3 = uk_marzo.iloc[0]
uk_4 = uk_abril.iloc[0]
uk_5 = uk_mayo.iloc[0]
uk_6 = uk_junio.iloc[0]
uk_7 = uk_julio.iloc[0]
uk_8 = uk_agosto.iloc[0]
uk_9 = uk_septiembre.iloc[0]

# %%
top_uk1 = pd.DataFrame(uk_1).T
top_uk2 = pd.DataFrame(uk_2).T
top_uk3 = pd.DataFrame(uk_3).T
top_uk4 = pd.DataFrame(uk_4).T
top_uk5 = pd.DataFrame(uk_5).T
top_uk6 = pd.DataFrame(uk_6).T
top_uk7 = pd.DataFrame(uk_7).T
top_uk8 = pd.DataFrame(uk_8).T
top_uk9 = pd.DataFrame(uk_9).T

# %%
top_uk = pd.concat([top_uk1, top_uk2, top_uk3, top_uk4, top_uk5, top_uk6, top_uk7, top_uk8, top_uk9], axis=0)

# %%
top_uk['date'] = ('2022-1-1', '2022-2-1', '2022-3-1', '2022-4-1', '2022-5-1', '2022-6-1', '2022-7-1', '2022-8-1', '2022-9-1')
top_uk['country'] = ('UK')

top_uk
# Out:
#   rank                                   uri  \
# 0    1  spotify:track:46IZ0fSY2mpAiktS3KOqds
# 0    1  spotify:track:52xJxFP6TqMuO4Yt0eOkMz
# 0    1  spotify:track:52xJxFP6TqMuO4Yt0eOkMz
# 0    1  spotify:track:4LRPiXqCikLlN15c3yImP7
# 0    1  spotify:track:4LRPiXqCikLlN15c3yImP7
# 0    1  spotify:track:75FEaRjZTKLhTrFGsfMUXR
# 0    1  spotify:track:75FEaRjZTKLhTrFGsfMUXR
# 0    1  spotify:track:75FEaRjZTKLhTrFGsfMUXR
# 0    1  spotify:track:4Dvkj6JhhA12EX05fT7y2e
#
#                                         artist_names  \
# 0                                              Adele
# 0  Carolina Gaitán - La Gaita, Mauro Castillo, Ad...
# 0  Carolina Gaitán - La Gaita, Mauro Castillo, Ad...
# 0                                       Harry Styles
# 0                                       Harry Styles
# 0                                          Kate Bush
# 0                                          Kate Bush
# 0                                          Kate Bush
# ...

# %% [markdown]
# # TOP 1 de Spotify en Alemania (Enero - Septiembre 2022):

# %%
#csv alemania

alemania_enero=pd.read_csv('../spotify/alemania_1_enero.csv')
alemania_febrero=pd.read_csv('../spotify/alemania_1_febrero.csv')
alemania_marzo=pd.read_csv('../spotify/alemania_1_marzo.csv')
alemania_abril=pd.read_csv('../spotify/alemania_1_abril.csv')
alemania_mayo=pd.read_csv('../spotify/alemania_1_mayo.csv')
alemania_junio=pd.read_csv('../spotify/alemania_1_junio.csv')
alemania_julio=pd.read_csv('../spotify/alemania_1_julio.csv')
alemania_agosto=pd.read_csv('../spotify/alemania_1_agosto.csv')
alemania_septiembre=pd.read_csv('../spotify/alemania_1_septiembre.csv')


alemania_enero.head()
# Out:
#    rank                                   uri                artist_names  \
# 0     1  spotify:track:5aoj3AXkJ7K2h5r8mmD6FS  Pajel, Luciano, Headie One
# 1     2  spotify:track:20on25jryn53hWghthWWW3             ACRAZE, Cherish
# 2     3  spotify:track:0pA0BVXTONNqSldC9FdiaU            Ufo361, Pashanim
# 3     4  spotify:track:4fouWK6XVHhzl78KzQ1UjL                       GAYLE
# 4     5  spotify:track:02MWAaffLxlfxAUY7c5dvx               Glass Animals
#
#         track_name                     source  peak_rank  previous_rank  \
# 0  10von10 - Remix                  Epic/DOPE          1              3
# 1      Do It To It          Thrive Music, LLC          1              1
# 2    allein allein                    ADS THC          1              8
# 3          abcdefu  Atlantic/Arthouse Records          1              6
# 4       Heat Waves            Polydor Records          1             10
#
#    days_on_chart  streams
# 0              2   306924
# 1             78   306895
# ...

# %%
alemania_1 = alemania_enero.iloc[0]
alemania_2 = alemania_febrero.iloc[0]
alemania_3 = alemania_marzo.iloc[0]
alemania_4 = alemania_abril.iloc[0]
alemania_5 = alemania_mayo.iloc[0]
alemania_6 = alemania_junio.iloc[0]
alemania_7 = alemania_julio.iloc[0]
alemania_8 = alemania_agosto.iloc[0]
alemania_9 = alemania_septiembre.iloc[0]

# %%
top_alemania1 = pd.DataFrame(alemania_1).T
top_alemania2 = pd.DataFrame(alemania_2).T
top_alemania3 = pd.DataFrame(alemania_3).T
top_alemania4 = pd.DataFrame(alemania_4).T
top_alemania5 = pd.DataFrame(alemania_5).T
top_alemania6 = pd.DataFrame(alemania_6).T
top_alemania7 = pd.DataFrame(alemania_7).T
top_alemania8 = pd.DataFrame(alemania_8).T
top_alemania9 = pd.DataFrame(alemania_9).T

# %%
top_alemania = pd.concat([top_alemania1, top_alemania2, top_alemania3, top_alemania4, top_alemania5, top_alemania6, top_alemania7, top_alemania8, top_alemania9], axis=0)

# %%
top_alemania['date'] = ('2022-1-1', '2022-2-1', '2022-3-1', '2022-4-1', '2022-5-1', '2022-6-1', '2022-7-1', '2022-8-1', '2022-9-1')
top_alemania['country'] = ('Germany')

top_alemania
# Out:
#   rank                                   uri                artist_names  \
# 0    1  spotify:track:5aoj3AXkJ7K2h5r8mmD6FS  Pajel, Luciano, Headie One
# 0    1  spotify:track:4fouWK6XVHhzl78KzQ1UjL                       GAYLE
# 0    1  spotify:track:0h14I7cPYi1RZG6GmVpMso                        CIVO
# 0    1  spotify:track:4LRPiXqCikLlN15c3yImP7                Harry Styles
# 0    1  spotify:track:2XRn6Qu0Wd1KvOND8JbaTx                     Luciano
# 0    1  spotify:track:2XRn6Qu0Wd1KvOND8JbaTx                     Luciano
# 0    1  spotify:track:3ujiq7yK4Uan5z4876fHLK           DJ Robin, Schürze
# 0    1  spotify:track:5ucyKDPjLpYLGadsRO1wSB           DJ Robin, Schürze
# 0    1  spotify:track:6yeZM8gyykjaf8w0GqRfK4                  Nina Chuba
#
#          track_name                                             source  \
# 0   10von10 - Remix                                          Epic/DOPE
# 0           abcdefu                          Atlantic/Arthouse Records
# ...

# %% [markdown]
# # TOP 1 de Spotify en Australia (Enero - Septiembre 2022):

# %%
#csv autralia

australia_enero=pd.read_csv('../spotify/australia_1_enero.csv')
australia_febrero=pd.read_csv('../spotify/australia_1_febrero.csv')
australia_marzo=pd.read_csv('../spotify/australia_1_marzo.csv')
australia_abril=pd.read_csv('../spotify/australia_1_abril.csv')
australia_mayo=pd.read_csv('../spotify/australia_1_mayo.csv')
australia_junio=pd.read_csv('../spotify/australia_1_junio.csv')
australia_julio=pd.read_csv('../spotify/australia_1_julio.csv')
australia_agosto=pd.read_csv('../spotify/australia_1_agosto.csv')
australia_septiembre=pd.read_csv('../spotify/australia_1_septiembre.csv')


australia_enero.head()
# Out:
#    rank                                   uri                  artist_names  \
# 0     1  spotify:track:7rglLriMNBPAyuJOMGwi39    Elton John, Dua Lipa, PNAU
# 1     2  spotify:track:5PjdY0CKGZdEuoNab3yDmX  The Kid LAROI, Justin Bieber
# 2     3  spotify:track:02MWAaffLxlfxAUY7c5dvx                 Glass Animals
# 3     4  spotify:track:4fouWK6XVHhzl78KzQ1UjL                         GAYLE
# 4     5  spotify:track:46IZ0fSY2mpAiktS3KOqds                         Adele
#
#                   track_name                     source  peak_rank  \
# 0    Cold Heart - PNAU Remix                        EMI          1
# 1  STAY (with Justin Bieber)                   Columbia          1
# 2                 Heat Waves            Polydor Records          1
# 3                    abcdefu  Atlantic/Arthouse Records          3
# 4                 Easy On Me                   Columbia          1
#
#    previous_rank  days_on_chart  streams
# 0              1            142   175696
# ...

# %%
australia_1 = australia_enero.iloc[0]
australia_2 = australia_febrero.iloc[0]
australia_3 = australia_marzo.iloc[0]
australia_4 = australia_abril.iloc[0]
australia_5 = australia_mayo.iloc[0]
australia_6 = australia_junio.iloc[0]
australia_7 = australia_julio.iloc[0]
australia_8 = australia_agosto.iloc[0]
australia_9 = australia_septiembre.iloc[0]

# %%
top_australia1 = pd.DataFrame(australia_1).T
top_australia2 = pd.DataFrame(australia_2).T
top_australia3 = pd.DataFrame(australia_3).T
top_australia4 = pd.DataFrame(australia_4).T
top_australia5 = pd.DataFrame(australia_5).T
top_australia6 = pd.DataFrame(australia_6).T
top_australia7 = pd.DataFrame(australia_7).T
top_australia8 = pd.DataFrame(australia_8).T
top_australia9 = pd.DataFrame(australia_9).T

# %%
top_australia = pd.concat([top_australia1, top_australia2, top_australia3, top_australia4, top_australia5, top_australia6, top_australia7, top_australia8, top_australia9], axis=0)

# %%
top_australia['date'] = ('2022-1-1', '2022-2-1', '2022-3-1', '2022-4-1', '2022-5-1', '2022-6-1', '2022-7-1', '2022-8-1', '2022-9-1')
top_australia['country'] = ('Australia')

top_australia
# Out:
#   rank                                   uri                  artist_names  \
# 0    1  spotify:track:7rglLriMNBPAyuJOMGwi39    Elton John, Dua Lipa, PNAU
# 0    1  spotify:track:5PjdY0CKGZdEuoNab3yDmX  The Kid LAROI, Justin Bieber
# 0    1  spotify:track:02MWAaffLxlfxAUY7c5dvx                 Glass Animals
# 0    1  spotify:track:4LRPiXqCikLlN15c3yImP7                  Harry Styles
# 0    1  spotify:track:4LRPiXqCikLlN15c3yImP7                  Harry Styles
# 0    1  spotify:track:75FEaRjZTKLhTrFGsfMUXR                     Kate Bush
# 0    1  spotify:track:75FEaRjZTKLhTrFGsfMUXR                     Kate Bush
# 0    1  spotify:track:75FEaRjZTKLhTrFGsfMUXR                     Kate Bush
# 0    1  spotify:track:2yjlYDiNiQkdxVqTlaSrlX                   Nicki Minaj
#
#                                track_name            source peak_rank  \
# 0                 Cold Heart - PNAU Remix               EMI         1
# 0               STAY (with Justin Bieber)          Columbia         1
# ...

# %% [markdown]
# # TOP 1 de Spotify en Corea del Sur (Enero - Septiembre 2022):

# %%
#csv korea

korea_enero=pd.read_csv('../spotify/korea_1_enero.csv')
korea_febrero=pd.read_csv('../spotify/korea_1_febrero.csv')
korea_marzo=pd.read_csv('../spotify/korea_1_marzo.csv')
korea_abril=pd.read_csv('../spotify/korea_1_abril.csv')
korea_mayo=pd.read_csv('../spotify/korea_1_mayo.csv')
korea_junio=pd.read_csv('../spotify/korea_1_junio.csv')
korea_julio=pd.read_csv('../spotify/korea_1_julio.csv')
korea_agosto=pd.read_csv('../spotify/korea_1_agosto.csv')
korea_septiembre=pd.read_csv('../spotify/korea_1_septiembre.csv')


korea_enero.head()
# Out:
#    rank                                   uri                artist_names  \
# 0     1  spotify:track:2eLe81VDUQ5f0xFfc9cMWz  sokodomo, Zion.T, Wonstein
# 1     2  spotify:track:7n2FZQsaLb7ZRfRPfEeIvr                         IVE
# 2     3  spotify:track:6rVCUwfnuYTAsX4P9fIdIu                       aespa
# 3     4  spotify:track:5g2Ik0WJG9rqu97nCLcQhV                  BE'O, MINO
# 4     5  spotify:track:2y4hHM6c48Qzk0bqh33XfB                          IU
#
#                                           track_name                   source  \
# 0  MERRY-GO-ROUND (Feat. Zion.T, Wonstein) (Prod....  Genie Music Corporation
# 1                                             ELEVEN   STARSHIP Entertainment
# 2                                   Dreams Come True         SM Entertainment
# 3                Limousine (Feat. MINO) (Prod. GRAY)  Genie Music Corporation
# 4                                       Winter Sleep       EDAM Entertainment
#
#    peak_rank  previous_rank  days_on_chart  streams
# ...

# %%
korea_1 = korea_enero.iloc[0]
korea_2 = korea_febrero.iloc[0]
korea_3 = korea_marzo.iloc[0]
korea_4 = korea_abril.iloc[0]
korea_5 = korea_mayo.iloc[0]
korea_6 = korea_junio.iloc[0]
korea_7 = korea_julio.iloc[0]
korea_8 = korea_agosto.iloc[0]
korea_9 = korea_septiembre.iloc[0]

# %%
top_korea1 = pd.DataFrame(korea_1).T
top_korea2 = pd.DataFrame(korea_2).T
top_korea3 = pd.DataFrame(korea_3).T
top_korea4 = pd.DataFrame(korea_4).T
top_korea5 = pd.DataFrame(korea_5).T
top_korea6 = pd.DataFrame(korea_6).T
top_korea7 = pd.DataFrame(korea_7).T
top_korea8 = pd.DataFrame(korea_8).T
top_korea9 = pd.DataFrame(korea_9).T

# %%
top_korea = pd.concat([top_korea1, top_korea2, top_korea3, top_korea4, top_korea5, top_korea6, top_korea7, top_korea8, top_korea9], axis=0)

# %%
top_korea['date'] = ('2022-1-1', '2022-2-1', '2022-3-1', '2022-4-1', '2022-5-1', '2022-6-1', '2022-7-1', '2022-8-1', '2022-9-1')
top_korea['country'] = ('Korea')

top_korea
# Out:
#   rank                                   uri                  artist_names  \
# 0    1  spotify:track:2eLe81VDUQ5f0xFfc9cMWz    sokodomo, Zion.T, Wonstein
# 0    1  spotify:track:186NCtNk1tUYS7c2DxgJ7O                             V
# 0    1  spotify:track:7rXcCpIAoOUCydkVDMcoPV                       TAEYEON
# 0    1  spotify:track:2oBMZYteeO8DyXV9gDx6Za                    Red Velvet
# 0    1  spotify:track:0Q5VnK2DYzRyfqQRJuUtvi                           IVE
# 0    1  spotify:track:0Q5VnK2DYzRyfqQRJuUtvi                           IVE
# 0    1  spotify:track:0mBP9X2gPCuapvpZ7TGDk3  Charlie Puth, Jung Kook, BTS
# 0    1  spotify:track:2pIUpMhHL6L9Z5lnKxJJr9                      NewJeans
# 0    1  spotify:track:2gYj9lubBorOPIVWsTXugG                           IVE
#
#                                           track_name                   source  \
# 0  MERRY-GO-ROUND (Feat. Zion.T, Wonstein) (Prod....  Genie Music Corporation
# ...

# %% [markdown]
# # TOP 1 de Spotify en Japón (Enero - Septiembre 2022):

# %%
#csv japon

japon_enero=pd.read_csv('../spotify/japon_1_enero.csv')
japon_febrero=pd.read_csv('../spotify/japon_1_febrero.csv')
japon_marzo=pd.read_csv('../spotify/japon_1_marzo.csv')
japon_abril=pd.read_csv('../spotify/japon_1_abril.csv')
japon_mayo=pd.read_csv('../spotify/japon_1_mayo.csv')
japon_junio=pd.read_csv('../spotify/japon_1_junio.csv')
japon_julio=pd.read_csv('../spotify/japon_1_julio.csv')
japon_agosto=pd.read_csv('../spotify/japon_1_agosto.csv')
japon_septiembre=pd.read_csv('../spotify/japon_1_septiembre.csv')


japon_enero.head()
# Out:
#    rank                                   uri      artist_names track_name  \
# 0     1  spotify:track:7ncPjJBktLEOpstY5JOUMK          King Gnu         一途
# 1     2  spotify:track:2sf18cEv463VgqmdjDsFpw             Yuuri     ベテルギウス
# 2     3  spotify:track:2PFzK3kMDDYKhGnugvNYf1  Macaroni Empitsu   なんでもないよ、
# 3     4  spotify:track:3ciqhcLmXP4hVGBD98QlEj        Fujii Kaze        きらり
# 4     5  spotify:track:7dH0dpi751EoguDDg3xx6J             Yuuri    ドライフラワー
#
#                    source  peak_rank  previous_rank  days_on_chart  streams
# 0  Sony Music Labels Inc.          1              1             24   180289
# 1  Sony Music Labels Inc.          1              2             59   169892
# 2           Toy's Factory          3              4             60   162580
# 3     Universal Music LLC          3             10            245   158996
# 4  Sony Music Labels Inc.          1              3            427   156600

# %%
japon_1 = japon_enero.iloc[0]
japon_2 = japon_febrero.iloc[0]
japon_3 = japon_marzo.iloc[0]
japon_4 = japon_abril.iloc[0]
japon_5 = japon_mayo.iloc[0]
japon_6 = japon_junio.iloc[0]
japon_7 = japon_julio.iloc[0]
japon_8 = japon_agosto.iloc[0]
japon_9 = japon_septiembre.iloc[0]

# %%
top_japon1 = pd.DataFrame(japon_1).T
top_japon2 = pd.DataFrame(japon_2).T
top_japon3 = pd.DataFrame(japon_3).T
top_japon4 = pd.DataFrame(japon_4).T
top_japon5 = pd.DataFrame(japon_5).T
top_japon6 = pd.DataFrame(japon_6).T
top_japon7 = pd.DataFrame(japon_7).T
top_japon8 = pd.DataFrame(japon_8).T
top_japon9 = pd.DataFrame(japon_9).T

# %%
top_japon = pd.concat([top_japon1, top_japon2, top_japon3, top_japon4, top_japon5, top_japon6, top_japon7, top_japon8, top_japon9], axis=0)

# %%
top_japon['date'] = ('2022-1-1', '2022-2-1', '2022-3-1', '2022-4-1', '2022-5-1', '2022-6-1', '2022-7-1', '2022-8-1', '2022-9-1')
top_japon['country'] = ('Japan')

top_japon
# Out:
#   rank                                   uri           artist_names  \
# 0    1  spotify:track:7ncPjJBktLEOpstY5JOUMK               King Gnu
# 0    1  spotify:track:5W7Y92LB4jWvu9NeEQ0GZl       Macaroni Empitsu
# 0    1  spotify:track:7v8wKvNQQIxkugCFFjrkaO                  Aimer
# 0    1  spotify:track:4JK1kDUdH9RTBQrrSO1QfR                  Yuuri
# 0    1  spotify:track:4IfrM44LofE9bSs6TDZS49             Tani Yuuki
# 0    1  spotify:track:4IfrM44LofE9bSs6TDZS49             Tani Yuuki
# 0    1  spotify:track:60ReNXcPcsVFd7nUuQw5HZ  Official HIGE DANdism
# 0    1  spotify:track:4IfrM44LofE9bSs6TDZS49             Tani Yuuki
# 0    1  spotify:track:28MATCYDctW5EiBa2repxb                    Ado
#
#    track_name                  source peak_rank previous_rank days_on_chart  \
# 0          一途  Sony Music Labels Inc.         1             1            24
# 0    なんでもないよ、           Toy's Factory         1             1            91
# ...

# %% [markdown]
# # Creamos tabla con todos los tops de cada país

# %%
top_mundial_mix = pd.concat([top_canada, top_usa, top_argentina, top_colombia, top_spain, top_uk, top_alemania, top_australia, top_korea, top_japon], axis=0)
top_mundial_mix
# Out:
#    rank                                   uri  \
# 0     1  spotify:track:7rglLriMNBPAyuJOMGwi39
# 0     1  spotify:track:52xJxFP6TqMuO4Yt0eOkMz
# 0     1  spotify:track:02MWAaffLxlfxAUY7c5dvx
# 0     1  spotify:track:4LRPiXqCikLlN15c3yImP7
# 0     1  spotify:track:4LRPiXqCikLlN15c3yImP7
# ..  ...                                   ...
# 0     1  spotify:track:4IfrM44LofE9bSs6TDZS49
# 0     1  spotify:track:4IfrM44LofE9bSs6TDZS49
# 0     1  spotify:track:60ReNXcPcsVFd7nUuQw5HZ
# 0     1  spotify:track:4IfrM44LofE9bSs6TDZS49
# 0     1  spotify:track:28MATCYDctW5EiBa2repxb
#
#                                          artist_names  \
# 0                          Elton John, Dua Lipa, PNAU
# 0   Carolina Gaitán - La Gaita, Mauro Castillo, Ad...
# 0                                       Glass Animals
# 0                                        Harry Styles
# 0                                        Harry Styles
# ..                                                ...
# ...

# %% [markdown]
# # Borramos las columnas que no necesitamos

# %%
top_mundial = top_mundial_mix.drop(['peak_rank','previous_rank','days_on_chart'], axis = 1)
top_mundial
# Out:
#    rank                                   uri  \
# 0     1  spotify:track:7rglLriMNBPAyuJOMGwi39
# 0     1  spotify:track:52xJxFP6TqMuO4Yt0eOkMz
# 0     1  spotify:track:02MWAaffLxlfxAUY7c5dvx
# 0     1  spotify:track:4LRPiXqCikLlN15c3yImP7
# 0     1  spotify:track:4LRPiXqCikLlN15c3yImP7
# ..  ...                                   ...
# 0     1  spotify:track:4IfrM44LofE9bSs6TDZS49
# 0     1  spotify:track:4IfrM44LofE9bSs6TDZS49
# 0     1  spotify:track:60ReNXcPcsVFd7nUuQw5HZ
# 0     1  spotify:track:4IfrM44LofE9bSs6TDZS49
# 0     1  spotify:track:28MATCYDctW5EiBa2repxb
#
#                                          artist_names  \
# 0                          Elton John, Dua Lipa, PNAU
# 0   Carolina Gaitán - La Gaita, Mauro Castillo, Ad...
# 0                                       Glass Animals
# 0                                        Harry Styles
# 0                                        Harry Styles
# ..                                                ...
# ...

# %%
top_mundial.to_csv('top_mundial.csv', index=False, sep=';')

# %% [markdown]
# # Añadimos la columna id_country

# %%
top_mundial
# Out:
#    rank                                   uri  \
# 0     1  spotify:track:7rglLriMNBPAyuJOMGwi39
# 0     1  spotify:track:52xJxFP6TqMuO4Yt0eOkMz
# 0     1  spotify:track:02MWAaffLxlfxAUY7c5dvx
# 0     1  spotify:track:4LRPiXqCikLlN15c3yImP7
# 0     1  spotify:track:4LRPiXqCikLlN15c3yImP7
# ..  ...                                   ...
# 0     1  spotify:track:4IfrM44LofE9bSs6TDZS49
# 0     1  spotify:track:4IfrM44LofE9bSs6TDZS49
# 0     1  spotify:track:60ReNXcPcsVFd7nUuQw5HZ
# 0     1  spotify:track:4IfrM44LofE9bSs6TDZS49
# 0     1  spotify:track:28MATCYDctW5EiBa2repxb
#
#                                          artist_names  \
# 0                          Elton John, Dua Lipa, PNAU
# 0   Carolina Gaitán - La Gaita, Mauro Castillo, Ad...
# 0                                       Glass Animals
# 0                                        Harry Styles
# 0                                        Harry Styles
# ..                                                ...
# ...

# %% [markdown]
# # Añadimos el número del id_country que hemos sacado en scrapping

# %%
top_mundial['id_country'] = ''
top_mundial['id_country'] = ['31' if x == 'Canada' else '188' if x == 'USA' else '7' if x == 'Argentina' else '37' if x == 'Colombia' else '165' if x == 'Spain' else '187' if x == 'UK' else '65' if x == 'Germany' else '9' if x == 'Australia' else '91' if x == 'Korea' else '85' if x == 'Japan' else '' for x in top_mundial['country']]
top_mundial
# Out:
#    rank                                   uri  \
# 0     1  spotify:track:7rglLriMNBPAyuJOMGwi39
# 0     1  spotify:track:52xJxFP6TqMuO4Yt0eOkMz
# 0     1  spotify:track:02MWAaffLxlfxAUY7c5dvx
# 0     1  spotify:track:4LRPiXqCikLlN15c3yImP7
# 0     1  spotify:track:4LRPiXqCikLlN15c3yImP7
# ..  ...                                   ...
# 0     1  spotify:track:4IfrM44LofE9bSs6TDZS49
# 0     1  spotify:track:4IfrM44LofE9bSs6TDZS49
# 0     1  spotify:track:60ReNXcPcsVFd7nUuQw5HZ
# 0     1  spotify:track:4IfrM44LofE9bSs6TDZS49
# 0     1  spotify:track:28MATCYDctW5EiBa2repxb
#
#                                          artist_names  \
# 0                          Elton John, Dua Lipa, PNAU
# 0   Carolina Gaitán - La Gaita, Mauro Castillo, Ad...
# 0                                       Glass Animals
# 0                                        Harry Styles
# 0                                        Harry Styles
# ..                                                ...
# ...

# %%
top_mundial['id_spotify']=np.arange(1,len(top_mundial)+1)
top_mundial
# Out:
#    rank                                   uri  \
# 0     1  spotify:track:7rglLriMNBPAyuJOMGwi39
# 0     1  spotify:track:52xJxFP6TqMuO4Yt0eOkMz
# 0     1  spotify:track:02MWAaffLxlfxAUY7c5dvx
# 0     1  spotify:track:4LRPiXqCikLlN15c3yImP7
# 0     1  spotify:track:4LRPiXqCikLlN15c3yImP7
# ..  ...                                   ...
# 0     1  spotify:track:4IfrM44LofE9bSs6TDZS49
# 0     1  spotify:track:4IfrM44LofE9bSs6TDZS49
# 0     1  spotify:track:60ReNXcPcsVFd7nUuQw5HZ
# 0     1  spotify:track:4IfrM44LofE9bSs6TDZS49
# 0     1  spotify:track:28MATCYDctW5EiBa2repxb
#
#                                          artist_names  \
# 0                          Elton John, Dua Lipa, PNAU
# 0   Carolina Gaitán - La Gaita, Mauro Castillo, Ad...
# 0                                       Glass Animals
# 0                                        Harry Styles
# 0                                        Harry Styles
# ..                                                ...
# ...

# %%
first_column = top_mundial.pop('id_spotify') 
  
top_mundial.insert(0, 'id_spotify', first_column)
top_mundial
# Out:
#     id_spotify rank                                   uri  \
# 0            1    1  spotify:track:7rglLriMNBPAyuJOMGwi39
# 0            2    1  spotify:track:52xJxFP6TqMuO4Yt0eOkMz
# 0            3    1  spotify:track:02MWAaffLxlfxAUY7c5dvx
# 0            4    1  spotify:track:4LRPiXqCikLlN15c3yImP7
# 0            5    1  spotify:track:4LRPiXqCikLlN15c3yImP7
# ..         ...  ...                                   ...
# 0           86    1  spotify:track:4IfrM44LofE9bSs6TDZS49
# 0           87    1  spotify:track:4IfrM44LofE9bSs6TDZS49
# 0           88    1  spotify:track:60ReNXcPcsVFd7nUuQw5HZ
# 0           89    1  spotify:track:4IfrM44LofE9bSs6TDZS49
# 0           90    1  spotify:track:28MATCYDctW5EiBa2repxb
#
#                                          artist_names  \
# 0                          Elton John, Dua Lipa, PNAU
# 0   Carolina Gaitán - La Gaita, Mauro Castillo, Ad...
# 0                                       Glass Animals
# ...

# %%
top_mundial.to_excel('top_mundial.xls', index=False)
# Out:
# /var/folders/x5/35_m562959z2k_v0h2llkrzr0000gn/T/ipykernel_5557/2861151337.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   top_mundial.to_excel('top_mundial.xls', index=False)
